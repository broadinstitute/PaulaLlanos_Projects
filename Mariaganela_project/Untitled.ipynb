# %%
import pandas as pd


conditions = {
    'B02': 'Control',
    'B03': 'Control',
    'B04': 'Control',
    'B05': 'Control',
    'B06': 'Control',
    'B07': 'Control',
    'B08': 'Control',
    'C02': 'Control',
    'C03': 'Control',
    'C04': 'Control',
    'C05': 'Control',
    'C06': 'Control',
    'C07': 'Control',
    'C08': 'Control',
    'D02': '5um',
    'D03': '5um',
    'D04': '5um',
    'D05': '5um',
    'D06': '5um',
    'D07': '5um',
    'D08': '5um',
    'E02': '5um',
    'E03': '5um',
    'E04': '5um',
    'E05': '5um',
    'E06': '5um',
    'E07': '5um',
    'E08': '5um',
    'F02': '100ng',
    'F03': '100ng',
    'F04': '100ng',
    'F05': '100ng',
    'F06': '100ng',
    'F07': '100ng',
    'F08': '100ng',
    'G02': '100ng',
    'G03': '100ng',
    'G04': '100ng',
    'G05': '100ng',
    'G06': '100ng',
    'G07': '100ng',
    'G08': '100ng',
}


conditions_type = {
    'B02': 'Parental',
    'B03': 'Colony 1',
    'B04': 'Colony 2',
    'B05': 'Colony 3',
    'B06': 'Colony 4',
    'B07': 'Colony 5',
    'B08': 'HeLa WT',
    'C02': 'Parental',
    'C03': 'Colony 1',
    'C04': 'Colony 2',
    'C05': 'Colony 3',
    'C06': 'Colony 4',
    'C07': 'Colony 5',
    'C08': 'HeLa WT',
    'D02': 'Parental',
    'D03': 'Colony 1',
    'D04': 'Colony 2',
    'D05': 'Colony 3',
    'D06': 'Colony 4',
    'D07': 'Colony 5',
    'D08': 'HeLa WT',
    'E02': 'Parental',
    'E03': 'Colony 1',
    'E04': 'Colony 2',
    'E05': 'Colony 3',
    'E06': 'Colony 4',
    'E07': 'Colony 5',
    'E08': 'HeLa WT',
    'F02': 'Parental',
    'F03': 'Colony 1',
    'F04': 'Colony 2',
    'F05': 'Colony 3',
    'F06': 'Colony 4',
    'F07': 'Colony 5',
    'F08': 'HeLa WT',
    'G02': 'Parental',
    'G03': 'Colony 1',
    'G04': 'Colony 2',
    'G05': 'Colony 3',
    'G06': 'Colony 4',
    'G07': 'Colony 5',
    'G08': 'HeLa WT',
}



conditions_Cargo = {
    'B02': 'None',
    'B03': 'None',
    'B04': 'None',
    'B05': 'None',
    'B06': 'None',
    'B07': 'None',
    'B08': 'None',
    'C02': 'None',
    'C03': 'None',
    'C04': 'None',
    'C05': 'None',
    'C06': 'None',
    'C07': 'None',
    'C08': 'None',
    'D02': 'UNC',
    'D03': 'UNC',
    'D04': 'UNC',
    'D05': 'UNC',
    'D06': 'UNC',
    'D07': 'UNC',
    'D08': 'UNC',
    'E02': 'UNC',
    'E03': 'UNC',
    'E04': 'UNC',
    'E05': 'UNC',
    'E06': 'UNC',
    'E07': 'UNC',
    'E08': 'UNC',
    'F02': 'LNP',
    'F03': 'LNP',
    'F04': 'LNP',
    'F05': 'LNP',
    'F06': 'LNP',
    'F07': 'LNP',
    'F08': 'LNP',
    'G02': 'LNP',
    'G03': 'LNP',
    'G04': 'LNP',
    'G05': 'LNP',
    'G06': 'LNP',
    'G07': 'LNP',
    'G08': 'LNP',
}

# %%
# Example dictionaries


# Convert dictionaries to DataFrames
df1 = pd.DataFrame(conditions, index=list(range(1, 43)))
df2 = pd.DataFrame(conditions_Cargo, index=list(range(43, 86)))

# Concatenate DataFrames
result_df = pd.concat([df1, df2], ignore_index=True)

# Drop columns with duplicate values
result_df = result_df.T.drop_duplicates().T

# Display the resulting DataFrame
result_df.head(50)
# Out:
#         B02  D02    F02
# 0   Control  5um  100ng
# 1   Control  5um  100ng
# 2   Control  5um  100ng
# 3   Control  5um  100ng
# 4   Control  5um  100ng
# 5   Control  5um  100ng
# 6   Control  5um  100ng
# 7   Control  5um  100ng
# 8   Control  5um  100ng
# 9   Control  5um  100ng
# 10  Control  5um  100ng
# 11  Control  5um  100ng
# 12  Control  5um  100ng
# 13  Control  5um  100ng
# 14  Control  5um  100ng
# 15  Control  5um  100ng
# 16  Control  5um  100ng
# 17  Control  5um  100ng
# 18  Control  5um  100ng
# 19  Control  5um  100ng
# 20  Control  5um  100ng
# 21  Control  5um  100ng
# 22  Control  5um  100ng
# 23  Control  5um  100ng
# 24  Control  5um  100ng
# 25  Control  5um  100ng
# 26  Control  5um  100ng
# 27  Control  5um  100ng
# 28  Control  5um  100ng
# 29  Control  5um  100ng
# 30  Control  5um  100ng
# 31  Control  5um  100ng
# 32  Control  5um  100ng
# 33  Control  5um  100ng
# 34  Control  5um  100ng
# 35  Control  5um  100ng
# 36  Control  5um  100ng
# 37  Control  5um  100ng
# 38  Control  5um  100ng
# 39  Control  5um  100ng
# 40  Control  5um  100ng
# 41  Control  5um  100ng
# 42     None  UNC    LNP
# 43     None  UNC    LNP
# 44     None  UNC    LNP
# 45     None  UNC    LNP
# 46     None  UNC    LNP
# 47     None  UNC    LNP
# 48     None  UNC    LNP
# 49     None  UNC    LNP
